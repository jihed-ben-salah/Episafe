# %%
#pip install sagemaker

# %%
#pip install --upgrade pip

# %%
import boto3

# Configure your AWS credentials
session = boto3.Session(
    aws_access_key_id='AKIA33JKKDZRFY3RNVMB',
    aws_secret_access_key='94vAqNZAWPTfu5jtriUvy5b3SNxyK/DMXtx46ngg',
    region_name='us-west-1'  
)

# Create SageMaker client
s3_client = session.client('sagemaker')

response = s3_client.list_notebook_instances()
for instance in response['NotebookInstances']:
    print(instance['NotebookInstanceName'])

# %%
#pip install pyarrow

# %%
import boto3
import pandas as pd
import pyarrow.parquet as pq

# %%
# establishing connection with the s3
s3_client = boto3.client('s3')
bucket_name = 'episafe-data'

# %%
# data fetching using s" client connection 
objects = s3_client.list_objects(Bucket=bucket_name)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...
